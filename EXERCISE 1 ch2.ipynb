# %%
import networkx as nx

# %%
G = nx.DiGraph()
G.add_edges_from([('Indianapolis','a'),('a','b'),('b','c'),('c','Fairbanks')])
nx.draw(G,with_labels=True,node_color='yellow',node_size=1600,font_color='red',font_size=16)

# %%
nx.has_path(G,'Indianapolis','Fairbanks')
# Out:
# True

# %%
list(nx.all_simple_paths(G,'Indianapolis','Fairbanks'))
# Out:
# [['Indianapolis', 'a', 'b', 'c', 'Fairbanks']]
